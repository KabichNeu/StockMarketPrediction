# %% [markdown]
# <a href="https://colab.research.google.com/github/KabichNeu/StockMarketPrediction/blob/master/extractingNabilData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/My Drive/Kaggle"

# %%
# %cd /content/gdrive/My Drive/Kaggle
# Out:
# /content/gdrive/My Drive/Kaggle

# %%
pwd
# Out:
# '/content/gdrive/My Drive/Kaggle'

# %%
# !kaggle datasets download -d sagyamthapa/nepali-stock-market-form-2012-to-2020-till-march
# Out:
# nepali-stock-market-form-2012-to-2020-till-march.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !ls
# Out:
#  kaggle.json
# 'Nepali_Stock_Market _Data__2012-2020'
#  nepali-stock-market-form-2012-to-2020-till-march.zip
#  OHLC.csv

# %%
# !unzip \*.zip  && rm *.zip
# Out:
# Archive:  nepali-stock-market-form-2012-to-2020-till-march.zip
# replace Nepali_Stock_Market _Data__2012-2020/2012/2012-01-01.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace Nepali_Stock_Market _Data__2012-2020/2012/2012-01-02.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: Nepali_Stock_Market _Data__2012-2020/2012/2012-01-02.csv
#   inflating: Nepali_Stock_Market _Data__2012-2020/2012/2012-01-03.csv
#   inflating: Nepali_Stock_Market _Data__2012-2020/2012/2012-01-04.csv
#   inflating: Nepali_Stock_Market _Data__2012-2020/2012/2012-01-05.csv
#   inflating: Nepali_Stock_Market _Data__2012-2020/2012/2012-01-08.csv
#   inflating: Nepali_Stock_Market _Data__2012-2020/2012/2012-01-09.csv
#   inflating: Nepali_Stock_Market _Data__2012-2020/2012/2012-01-10.csv
#   inflating: Nepali_Stock_Market _Data__2012-2020/2012/2012-01-11.csv
#   inflating: Nepali_Stock_Market _Data__2012-2020/2012/2012-01-12.csv
# ...

# %%
import pandas as pd
import numpy as np
from scipy import sparse
raw_data = pd.read_csv('OHLC.csv', parse_dates = True, index_col = 0)
raw_data.head(200)
# Out:
#       Symbol            Date   Open   High    Low  Close     Vol
# S.no
# 0     ACEDBL  2012-01-01.csv  114.0  113.0  112.0  113.0   1,962
# 1     ACEDPO  2012-01-01.csv  188.0  114.0  114.0  114.0  10,000
# 2       ADBL  2012-01-01.csv  115.0  115.0  113.0  114.0   1,111
# 3       AHPC  2012-01-01.csv  319.0  319.0  312.0  312.0     377
# 4      ALDBL  2012-01-01.csv  102.0  101.0  101.0  101.0      30
# ...      ...             ...    ...    ...    ...    ...     ...
# 44       NCM  2012-01-03.csv  179.0  181.0  170.0  170.0   2,515
# 45      NDEP  2012-01-03.csv   85.0   87.0   85.0   85.0     512
# 46      NHPC  2012-01-03.csv   50.0   51.0   50.0   51.0   3,110
# 47       NIB  2012-01-03.csv  407.0  424.0  408.0  408.0   1,439
# 48      NICB  2012-01-03.csv  417.0  428.0  413.0  414.0   2,425
#
# [200 rows x 7 columns]

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 250901 entries, 0 to 121
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Symbol  250761 non-null  object
#  1   Date    250901 non-null  object
#  2   Open    250901 non-null  float64
#  3   High    250901 non-null  float64
#  4   Low     250901 non-null  float64
#  5   Close   250901 non-null  float64
#  6   Vol     250901 non-null  object
# dtypes: float64(4), object(3)
# memory usage: 15.3+ MB

# %%
#stock_data = raw_data.drop(['S.no'],axis=1)
stock_data
# Out:
#                  Open   High    Low  Close     Vol
# Date
# 2012-01-01.csv  114.0  113.0  112.0  113.0   1,962
# 2012-01-01.csv  188.0  114.0  114.0  114.0  10,000
# 2012-01-01.csv  115.0  115.0  113.0  114.0   1,111
# 2012-01-01.csv  319.0  319.0  312.0  312.0     377
# 2012-01-01.csv  102.0  101.0  101.0  101.0      30
# ...               ...    ...    ...    ...     ...
# 2020-03-22.csv  206.0  206.0  202.0  206.0   1,575
# 2020-03-22.csv  313.0  313.0  301.0  307.0     636
# 2020-03-22.csv  100.0  100.0  100.0  100.0     519
# 2020-03-22.csv   73.0   73.0   73.0   73.0      10
# 2020-03-22.csv  230.0  230.0  225.0  227.0   2,893
#
# [250901 rows x 5 columns]

# %%
#stock_data.set_index("Symbol", inplace = True)

# %%
stock_data
# Out:
#                  Open   High    Low  Close     Vol
# Date
# 2012-01-01.csv  114.0  113.0  112.0  113.0   1,962
# 2012-01-01.csv  188.0  114.0  114.0  114.0  10,000
# 2012-01-01.csv  115.0  115.0  113.0  114.0   1,111
# 2012-01-01.csv  319.0  319.0  312.0  312.0     377
# 2012-01-01.csv  102.0  101.0  101.0  101.0      30
# ...               ...    ...    ...    ...     ...
# 2020-03-22.csv  206.0  206.0  202.0  206.0   1,575
# 2020-03-22.csv  313.0  313.0  301.0  307.0     636
# 2020-03-22.csv  100.0  100.0  100.0  100.0     519
# 2020-03-22.csv   73.0   73.0   73.0   73.0      10
# 2020-03-22.csv  230.0  230.0  225.0  227.0   2,893
#
# [250901 rows x 5 columns]

# %%
nabil_data = stock_data.loc['NABIL']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# KeyError: 'NABIL'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-e96406f354c3> in <module>()
# ----> 1 nabil_data = stock_data.loc['NABIL']
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1766
# ...

# %%
nabil_data
# Out:
#                   Date   Open   High    Low  Close     Vol
# Symbol
# NABIL   2012-01-01.csv  873.0  879.0  851.0  879.0     799
# NABIL   2012-01-02.csv  879.0  913.0  882.0  900.0   1,002
# NABIL   2012-01-03.csv  900.0  916.0  892.0  892.0   2,653
# NABIL   2012-01-04.csv  892.0  875.0  842.0  865.0     490
# NABIL   2012-01-05.csv  865.0  875.0  858.0  858.0     121
# ...                ...    ...    ...    ...    ...     ...
# NABIL   2020-03-16.csv  741.0  764.0  723.0  750.0  55,501
# NABIL   2020-03-17.csv  765.0  765.0  721.0  731.0  46,620
# NABIL   2020-03-18.csv  731.0  739.0  700.0  715.0  43,913
# NABIL   2020-03-19.csv  701.0  740.0  690.0  730.0  55,806
# NABIL   2020-03-22.csv  744.0  744.0  700.0  701.0  15,101
#
# [1910 rows x 6 columns]

# %%
nabil_data['Date'].dtype
# Out:
# dtype('O')

# %%
nabil_data['Date'].replace('.csv','', regex=True, inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
nabil_data['Date']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-187ca7e40aa5> in <module>()
# ----> 1 nabil_data['Date']
#
# TypeError: 'NoneType' object is not subscriptable

# %%
import datetime
nabil_data['date_parsed'] = pd.to_datetime(nabil_data['Date'],infer_datetime_format= True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
nabil_data['date_parsed']
# Out:
# Symbol
# NABIL   2012-01-01
# NABIL   2012-01-02
# NABIL   2012-01-03
# NABIL   2012-01-04
# NABIL   2012-01-05
#            ...
# NABIL   2020-03-16
# NABIL   2020-03-17
# NABIL   2020-03-18
# NABIL   2020-03-19
# NABIL   2020-03-22
# Name: date_parsed, Length: 1910, dtype: datetime64[ns]

# %%
nabil_data

# %%
#nabil_data = nabil_data.drop(['Date'], axis =1)
